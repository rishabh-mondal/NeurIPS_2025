# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
history_path = "runs/bihar_to_test_bihar/history.csv"

df = pd.read_csv(history_path)
# display(df.head())

# %%
# columns in df
df.columns.tolist()
# Out:
# ['train_lr',
#  'train_class_error',
#  'train_loss',
#  'train_loss_ce',
#  'train_loss_bbox',
#  'train_loss_giou',
#  'train_loss_ce_0',
#  'train_loss_bbox_0',
#  'train_loss_giou_0',
#  'train_loss_ce_1',
#  'train_loss_bbox_1',
#  'train_loss_giou_1',
#  'train_loss_ce_enc',
#  'train_loss_bbox_enc',
#  'train_loss_giou_enc',
#  'train_loss_ce_unscaled',
#  'train_class_error_unscaled',
#  'train_loss_bbox_unscaled',
#  'train_loss_giou_unscaled',
#  'train_cardinality_error_unscaled',
#  'train_loss_ce_0_unscaled',
#  'train_loss_bbox_0_unscaled',
#  'train_loss_giou_0_unscaled',
#  'train_cardinality_error_0_unscaled',
#  'train_loss_ce_1_unscaled',
#  'train_loss_bbox_1_unscaled',
#  'train_loss_giou_1_unscaled',
#  'train_cardinality_error_1_unscaled',
#  'train_loss_ce_enc_unscaled',
#  'train_loss_bbox_enc_unscaled',
#  'train_loss_giou_enc_unscaled',
#  'train_cardinality_error_enc_unscaled',
#  'test_class_error',
#  'test_loss',
#  'test_loss_ce',
#  'test_loss_bbox',
#  'test_loss_giou',
#  'test_loss_ce_0',
#  'test_loss_bbox_0',
#  'test_loss_giou_0',
#  'test_loss_ce_1',
#  'test_loss_bbox_1',
#  'test_loss_giou_1',
#  'test_loss_ce_enc',
#  'test_loss_bbox_enc',
#  'test_loss_giou_enc',
#  'test_loss_ce_unscaled',
#  'test_class_error_unscaled',
#  'test_loss_bbox_unscaled',
#  'test_loss_giou_unscaled',
#  'test_cardinality_error_unscaled',
#  'test_loss_ce_0_unscaled',
#  'test_loss_bbox_0_unscaled',
#  'test_loss_giou_0_unscaled',
#  'test_cardinality_error_0_unscaled',
#  'test_loss_ce_1_unscaled',
#  'test_loss_bbox_1_unscaled',
#  'test_loss_giou_1_unscaled',
#  'test_cardinality_error_1_unscaled',
#  'test_loss_ce_enc_unscaled',
#  'test_loss_bbox_enc_unscaled',
#  'test_loss_giou_enc_unscaled',
#  'test_cardinality_error_enc_unscaled',
#  'test_coco_eval_bbox',
#  'epoch',
#  'n_parameters',
#  'ema_test_class_error',
#  'ema_test_loss',
#  'ema_test_loss_ce',
#  'ema_test_loss_bbox',
#  'ema_test_loss_giou',
#  'ema_test_loss_ce_0',
#  'ema_test_loss_bbox_0',
#  'ema_test_loss_giou_0',
#  'ema_test_loss_ce_1',
#  'ema_test_loss_bbox_1',
#  'ema_test_loss_giou_1',
#  'ema_test_loss_ce_enc',
#  'ema_test_loss_bbox_enc',
#  'ema_test_loss_giou_enc',
#  'ema_test_loss_ce_unscaled',
#  'ema_test_class_error_unscaled',
#  'ema_test_loss_bbox_unscaled',
#  'ema_test_loss_giou_unscaled',
#  'ema_test_cardinality_error_unscaled',
#  'ema_test_loss_ce_0_unscaled',
#  'ema_test_loss_bbox_0_unscaled',
#  'ema_test_loss_giou_0_unscaled',
#  'ema_test_cardinality_error_0_unscaled',
#  'ema_test_loss_ce_1_unscaled',
#  'ema_test_loss_bbox_1_unscaled',
#  'ema_test_loss_giou_1_unscaled',
#  'ema_test_cardinality_error_1_unscaled',
#  'ema_test_loss_ce_enc_unscaled',
#  'ema_test_loss_bbox_enc_unscaled',
#  'ema_test_loss_giou_enc_unscaled',
#  'ema_test_cardinality_error_enc_unscaled',
#  'ema_test_coco_eval_bbox',
#  'all_best_res',
#  'all_best_ep',
#  'regular_best_res',
#  'regular_best_ep',
#  'ema_best_res',
#  'ema_best_ep',
#  'now_time',
#  'train_epoch_time',
#  'epoch_time']

# %%
plt.figure(figsize=(12, 8))

plt.plot(
	df['epoch'],
	df['train_loss'],
	label='Training Loss',
	marker='o',
	linestyle='-'
)

plt.plot(
	df['epoch'],
	df['test_loss'],
	label='Validation Loss',
	marker='o',
	linestyle='--'
)

plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# plt.savefig('train_validation_loss.png')
plt.show()
